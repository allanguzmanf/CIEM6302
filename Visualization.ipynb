# %% [markdown]
# Kotug Project, Group 1
#
# Allan Guzman, June Chen, Sarah Blanc

# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import json
import matplotlib.pyplot as plt
from matplotlib.patches import FancyArrowPatch
from matplotlib.colors import Normalize
from matplotlib.cm import ScalarMappable
import matplotlib.patches as mpatches
from ipyleaflet import Map, GeoJSON, GeoData, basemaps, LayersControl
from shapely.geometry import Point, LineString
import dash
from dash import dcc, html
from dash.dependencies import Input, Output
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import folium

# %%
def flatten_dict(d, parent_key='', sep='_'):
    items = {}
    for k, v in d.items():
        new_key = f"{parent_key}{sep}{k}" if parent_key else k
        if isinstance(v, dict):
            items.update(flatten_dict(v, new_key, sep=sep))
        else:
            items[new_key] = v
    return items

# Opening JSON file
f = open('port_arthur.json')
 
# returns JSON object as a dictionary
data = json.load(f)
 
# Flatten each dictionary and store the results in a list
flattened_dicts = [flatten_dict(d) for d in data['data']]

# Create a DataFrame
data = pd.DataFrame(flattened_dicts)

# Closing file
f.close()

# %%
data['navigation_time'] = pd.to_datetime(data['navigation_time'])

data = data[
    (data['navigation_status'] != 'moored') &
    (data['navigation_speed'] != 0)
    ].drop_duplicates()

# %%
def create_point(row):
    return Point(row['navigation_location_long'], row['navigation_location_lat'])

data['geometry'] = data.apply(create_point, axis=1)

tugs = data.loc[(data['vessel_type'] == 'tug')].reset_index()
non_tug = data.loc[(data['vessel_type'] != 'tug')].reset_index()

# %%
tugs
# Out:
#      index vessel_type vessel_callsign vessel_subtype  vessel_imo vessel_name  \
# 0     1425         tug         WDD7182           None     9397391      SABINE
# 1     1426         tug         WDD7182           None     9397391      SABINE
# 2     1427         tug         WDD7182           None     9397391      SABINE
# 3     1428         tug         WDD7182           None     9397391      SABINE
# 4     1429         tug         WDD7182           None     9397391      SABINE
# ..     ...         ...             ...            ...         ...         ...
# 308   2129         tug         WDJ4094        regular     9812042      TRITON
# 309   2130         tug         WDJ4094        regular     9812042      TRITON
# 310   2131         tug         WDJ4094        regular     9812042      TRITON
# 311   2133         tug         WDJ4094        regular     9812042      TRITON
# 312   2142         tug         WDJ4094        regular     9812042      TRITON
#
#      navigation_draught       navigation_status  navigation_location_long  \
# 0                   4.0  under-way-using-engine                 -93.96003
# 1                   4.0  under-way-using-engine                 -93.96014
# 2                   4.0  under-way-using-engine                 -93.95980
# 3                   4.0  under-way-using-engine                 -93.95654
# 4                   4.0  under-way-using-engine                 -93.95659
# ..                  ...                     ...                       ...
# 308                 6.0  under-way-using-engine                 -93.93849
# 309                 6.0  under-way-using-engine                 -93.93849
# 310                 6.0  under-way-using-engine                 -93.93849
# 311                 6.0  under-way-using-engine                 -93.93850
# 312                 6.0  under-way-using-engine                 -93.93849
#
#      navigation_location_lat  navigation_speed           navigation_time  \
# 0                   29.82966               0.1 2021-04-07 19:06:58+00:00
# 1                   29.82968               1.0 2021-04-07 19:11:58+00:00
# 2                   29.82104               8.3 2021-04-07 19:16:59+00:00
# 3                   29.80986               8.3 2021-04-07 19:21:58+00:00
# 4                   29.81096               8.8 2021-04-07 19:26:59+00:00
# ..                       ...               ...                       ...
# 308                 29.86100               0.1 2021-04-08 06:56:52+00:00
# 309                 29.86100               0.1 2021-04-08 07:01:52+00:00
# 310                 29.86099               0.1 2021-04-08 07:06:51+00:00
# 311                 29.86097               0.1 2021-04-08 07:16:53+00:00
# 312                 29.86101               0.1 2021-04-08 08:02:00+00:00
#
#      navigation_course  device_mmsi  device_dimensions_to_bow  \
# 0                225.4    367182980                        15
# 1                256.3    367182980                        15
# 2                164.6    367182980                        15
# 3                162.6    367182980                        15
# 4                342.3    367182980                        15
# ..                 ...          ...                       ...
# 308              154.1    367774360                        16
# 309              196.6    367774360                        16
# 310              182.5    367774360                        16
# 311              196.7    367774360                        16
# 312               20.4    367774360                        16
#
#      device_dimensions_to_starboard  device_dimensions_to_stern  \
# 0                                 8                          15
# 1                                 8                          15
# 2                                 8                          15
# 3                                 8                          15
# 4                                 8                          15
# ..                              ...                         ...
# 308                              14                           7
# 309                              14                           7
# 310                              14                           7
# 311                              14                           7
# 312                              14                           7
#
#      device_dimensions_to_port                    geometry
# 0                            2  POINT (-93.96003 29.82966)
# 1                            2  POINT (-93.96014 29.82968)
# 2                            2   POINT (-93.9598 29.82104)
# 3                            2  POINT (-93.95654 29.80986)
# 4                            2  POINT (-93.95659 29.81096)
# ..                         ...                         ...
# 308                          6    POINT (-93.93849 29.861)
# 309                          6    POINT (-93.93849 29.861)
# 310                          6  POINT (-93.93849 29.86099)
# 311                          6   POINT (-93.9385 29.86097)
# 312                          6  POINT (-93.93849 29.86101)
#
# [313 rows x 19 columns]

# %%
merged_data = non_tug.merge(tugs,how= 'cross', suffixes = ('_nontug','_tug'))

# %%
merged_data
# Out:
#         index_nontug vessel_type_nontug vessel_callsign_nontug  \
# 0                  0             tanker                   EBZV
# 1                  0             tanker                   EBZV
# 2                  0             tanker                   EBZV
# 3                  0             tanker                   EBZV
# 4                  0             tanker                   EBZV
# ...              ...                ...                    ...
# 120187          1316             tanker                  3EZV4
# 120188          1316             tanker                  3EZV4
# 120189          1316             tanker                  3EZV4
# 120190          1316             tanker                  3EZV4
# 120191          1316             tanker                  3EZV4
#
#        vessel_subtype_nontug  vessel_imo_nontug vessel_name_nontug  \
# 0                        all            9236420   CATALUNYA SPIRIT
# 1                        all            9236420   CATALUNYA SPIRIT
# 2                        all            9236420   CATALUNYA SPIRIT
# 3                        all            9236420   CATALUNYA SPIRIT
# 4                        all            9236420   CATALUNYA SPIRIT
# ...                      ...                ...                ...
# 120187                   all            9397808        NINGBO DAWN
# 120188                   all            9397808        NINGBO DAWN
# 120189                   all            9397808        NINGBO DAWN
# 120190                   all            9397808        NINGBO DAWN
# 120191                   all            9397808        NINGBO DAWN
#
#         navigation_draught_nontug navigation_status_nontug  \
# 0                             9.6   under-way-using-engine
# 1                             9.6   under-way-using-engine
# 2                             9.6   under-way-using-engine
# 3                             9.6   under-way-using-engine
# 4                             9.6   under-way-using-engine
# ...                           ...                      ...
# 120187                       11.7   under-way-using-engine
# 120188                       11.7   under-way-using-engine
# 120189                       11.7   under-way-using-engine
# 120190                       11.7   under-way-using-engine
# 120191                       11.7   under-way-using-engine
#
#         navigation_location_long_nontug  navigation_location_lat_nontug  ...  \
# 0                             -93.70755                        29.41630  ...
# 1                             -93.70755                        29.41630  ...
# 2                             -93.70755                        29.41630  ...
# 3                             -93.70755                        29.41630  ...
# 4                             -93.70755                        29.41630  ...
# ...                                 ...                             ...  ...
# 120187                        -93.95630                        29.82242  ...
# 120188                        -93.95630                        29.82242  ...
# 120189                        -93.95630                        29.82242  ...
# 120190                        -93.95630                        29.82242  ...
# 120191                        -93.95630                        29.82242  ...
#
#         navigation_location_lat_tug navigation_speed_tug  \
# 0                          29.82966                  0.1
# 1                          29.82968                  1.0
# 2                          29.82104                  8.3
# 3                          29.80986                  8.3
# 4                          29.81096                  8.8
# ...                             ...                  ...
# 120187                     29.86100                  0.1
# 120188                     29.86100                  0.1
# 120189                     29.86099                  0.1
# 120190                     29.86097                  0.1
# 120191                     29.86101                  0.1
#
#              navigation_time_tug  navigation_course_tug  device_mmsi_tug  \
# 0      2021-04-07 19:06:58+00:00                  225.4        367182980
# 1      2021-04-07 19:11:58+00:00                  256.3        367182980
# 2      2021-04-07 19:16:59+00:00                  164.6        367182980
# 3      2021-04-07 19:21:58+00:00                  162.6        367182980
# 4      2021-04-07 19:26:59+00:00                  342.3        367182980
# ...                          ...                    ...              ...
# 120187 2021-04-08 06:56:52+00:00                  154.1        367774360
# 120188 2021-04-08 07:01:52+00:00                  196.6        367774360
# 120189 2021-04-08 07:06:51+00:00                  182.5        367774360
# 120190 2021-04-08 07:16:53+00:00                  196.7        367774360
# 120191 2021-04-08 08:02:00+00:00                   20.4        367774360
#
#         device_dimensions_to_bow_tug  device_dimensions_to_starboard_tug  \
# 0                                 15                                   8
# 1                                 15                                   8
# 2                                 15                                   8
# 3                                 15                                   8
# 4                                 15                                   8
# ...                              ...                                 ...
# 120187                            16                                  14
# 120188                            16                                  14
# 120189                            16                                  14
# 120190                            16                                  14
# 120191                            16                                  14
#
#         device_dimensions_to_stern_tug device_dimensions_to_port_tug  \
# 0                                   15                             2
# 1                                   15                             2
# 2                                   15                             2
# 3                                   15                             2
# 4                                   15                             2
# ...                                ...                           ...
# 120187                               7                             6
# 120188                               7                             6
# 120189                               7                             6
# 120190                               7                             6
# 120191                               7                             6
#
#                       geometry_tug
# 0       POINT (-93.96003 29.82966)
# 1       POINT (-93.96014 29.82968)
# 2        POINT (-93.9598 29.82104)
# 3       POINT (-93.95654 29.80986)
# 4       POINT (-93.95659 29.81096)
# ...                            ...
# 120187    POINT (-93.93849 29.861)
# 120188    POINT (-93.93849 29.861)
# 120189  POINT (-93.93849 29.86099)
# 120190   POINT (-93.9385 29.86097)
# 120191  POINT (-93.93849 29.86101)
#
# [120192 rows x 38 columns]

# %%
merged_data['time_diff'] = (merged_data['navigation_time_tug']-merged_data['navigation_time_nontug']).dt.total_seconds() / 60
merged_data['navigation_diff'] = abs(merged_data['navigation_course_tug']-merged_data['navigation_course_nontug'])
merged_data['speed_diff'] = abs(merged_data['navigation_speed_tug']-merged_data['navigation_speed_nontug'])

# %%
import numpy as np

# Function to calculate distance in kilometers using Haversine formula
def haversine(lat1, lon1, lat2, lon2):
    # Radius of the Earth in kilometers
    R = 6371.0
    
    # Convert latitude and longitude from degrees to radians
    lat1 = np.radians(lat1)
    lon1 = np.radians(lon1)
    lat2 = np.radians(lat2)
    lon2 = np.radians(lon2)
    
    # Haversine formula
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    a = np.sin(dlat/2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2)**2
    c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1-a))
    distance = R * c
    
    return distance

# Apply the haversine function to each row to create a new column 'distance_km'
merged_data['distance_km'] = merged_data.apply(lambda row: haversine(row['navigation_location_lat_nontug'], row['navigation_location_long_nontug'], row['navigation_location_lat_tug'], row['navigation_location_long_tug']), axis=1)

# %%
filtered_columns = merged_data[[
    'index_nontug','index_tug',
    'vessel_name_nontug','vessel_name_tug',
    'navigation_speed_nontug','navigation_speed_tug', 
    'navigation_course_nontug','navigation_course_tug',
    'speed_diff','navigation_diff', 'distance_km','time_diff',
    'navigation_time_nontug'
    ]]

# %%
filtered_columns = filtered_columns[ 
    (abs(merged_data['time_diff']) < 3) & 
    (merged_data['distance_km'] < 0.25 ) &
    (merged_data['navigation_diff'] < 10 ) &
    (merged_data['speed_diff'] < 1 ) ]

# %%
filtered_columns
# Out:
#        index_nontug  index_tug vessel_name_nontug vessel_name_tug  \
# 68238           639       1429            IRELAND          SABINE
# 68552           640       1430            IRELAND          SABINE
# 69180           642       1432            IRELAND          SABINE
# 69494           643       1433            IRELAND          SABINE
# 69808           644       1434            IRELAND          SABINE
# 70122           645       1435            IRELAND          SABINE
# 70436           646       1436            IRELAND          SABINE
# 70750           647       1437            IRELAND          SABINE
# 71064           648       1438            IRELAND          SABINE
# 71378           649       1439            IRELAND          SABINE
# 71692           650       1440            IRELAND          SABINE
# 72006           651       1441            IRELAND          SABINE
# 72320           652       1442            IRELAND          SABINE
# 72634           653       1443            IRELAND          SABINE
# 72948           654       1444            IRELAND          SABINE
# 73262           655       1445            IRELAND          SABINE
# 73576           656       1446            IRELAND          SABINE
# 73890           657       1447            IRELAND          SABINE
# 74204           658       1448            IRELAND          SABINE
# 74518           659       1449            IRELAND          SABINE
# 74832           660       1450            IRELAND          SABINE
# 75146           661       1451            IRELAND          SABINE
# 75460           662       1452            IRELAND          SABINE
# 75774           663       1453            IRELAND          SABINE
# 76088           664       1454            IRELAND          SABINE
# 76402           665       1455            IRELAND          SABINE
# 76716           666       1456            IRELAND          SABINE
# 77030           667       1457            IRELAND          SABINE
# 77344           668       1458            IRELAND          SABINE
# 77658           669       1459            IRELAND          SABINE
# 77972           670       1460            IRELAND          SABINE
# 78286           671       1461            IRELAND          SABINE
# 78914           673       1463            IRELAND          SABINE
# 79228           674       1464            IRELAND          SABINE
# 79542           675       1465            IRELAND          SABINE
# 79856           676       1466            IRELAND          SABINE
# 80170           677       1467            IRELAND          SABINE
# 80484           678       1468            IRELAND          SABINE
# 80798           679       1469            IRELAND          SABINE
# 81112           680       1470            IRELAND          SABINE
# 81426           681       1471            IRELAND          SABINE
# 81740           682       1472            IRELAND          SABINE
# 82368           684       1474            IRELAND          SABINE
# 82682           685       1475            IRELAND          SABINE
# 82996           686       1476            IRELAND          SABINE
# 83310           687       1477            IRELAND          SABINE
# 83624           688       1478            IRELAND          SABINE
# 83938           689       1479            IRELAND          SABINE
# 83963           689       1647            IRELAND       BUCCANEER
# 84252           690       1480            IRELAND          SABINE
# 84277           690       1648            IRELAND       BUCCANEER
# 84565           691       1480            IRELAND          SABINE
# 84590           691       1648            IRELAND       BUCCANEER
# 84880           693       1482            IRELAND          SABINE
# 84905           693       1650            IRELAND       BUCCANEER
#
#        navigation_speed_nontug  navigation_speed_tug  \
# 68238                      8.7                   8.8
# 68552                      8.0                   8.2
# 69180                      7.1                   7.2
# 69494                      5.5                   5.4
# 69808                      4.1                   4.0
# 70122                      3.9                   4.0
# 70436                      5.2                   5.4
# 70750                      7.4                   7.5
# 71064                      8.2                   8.3
# 71378                      8.6                   8.7
# 71692                      8.0                   8.0
# 72006                      7.6                   7.7
# 72320                      5.3                   5.3
# 72634                      5.1                   5.1
# 72948                      4.9                   4.6
# 73262                      3.8                   4.0
# 73576                      6.5                   6.6
# 73890                      7.5                   7.5
# 74204                      7.5                   6.7
# 74518                      6.3                   6.4
# 74832                      7.7                   7.8
# 75146                      7.5                   7.6
# 75460                      5.3                   5.3
# 75774                      5.5                   5.5
# 76088                      7.3                   7.4
# 76402                      8.3                   8.5
# 76716                      7.3                   7.4
# 77030                      4.3                   4.3
# 77344                      4.2                   4.3
# 77658                      4.1                   4.2
# 77972                      5.9                   6.0
# 78286                      7.3                   7.4
# 78914                      4.5                   4.7
# 79228                      3.6                   3.6
# 79542                      3.6                   3.6
# 79856                      4.3                   4.4
# 80170                      5.0                   5.0
# 80484                      7.2                   6.6
# 80798                      7.0                   6.9
# 81112                      4.4                   4.4
# 81426                      4.4                   4.4
# 81740                      4.2                   4.2
# 82368                      7.3                   7.4
# 82682                      7.5                   7.5
# 82996                      7.4                   7.5
# 83310                      5.8                   5.9
# 83624                      5.0                   4.8
# 83938                      3.4                   4.2
# 83963                      3.4                   3.7
# 84252                      3.6                   3.8
# 84277                      3.6                   3.7
# 84565                      3.7                   3.8
# 84590                      3.7                   3.7
# 84880                      3.1                   3.3
# 84905                      3.1                   3.5
#
#        navigation_course_nontug  navigation_course_tug  speed_diff  \
# 68238                     341.1                  342.3         0.1
# 68552                      14.4                    5.9         0.2
# 69180                      16.3                   11.3         0.1
# 69494                      39.6                   39.7         0.1
# 69808                      39.7                   42.6         0.1
# 70122                      41.2                   40.6         0.1
# 70436                      26.6                   33.7         0.2
# 70750                      37.8                   34.1         0.1
# 71064                      38.5                   38.1         0.1
# 71378                      37.8                   40.7         0.1
# 71692                      44.2                   45.3         0.0
# 72006                      36.2                   36.4         0.1
# 72320                      43.9                   47.9         0.0
# 72634                      39.4                   35.7         0.0
# 72948                      38.4                   36.1         0.3
# 73262                      37.9                   40.1         0.2
# 73576                      38.1                   36.3         0.1
# 73890                      16.9                   14.5         0.0
# 74204                      20.3                   16.8         0.8
# 74518                      22.5                   21.0         0.1
# 74832                     339.0                  342.7         0.1
# 75146                     289.3                  286.6         0.1
# 75460                     279.3                  281.2         0.0
# 75774                     279.1                  279.6         0.0
# 76088                     281.7                  274.7         0.1
# 76402                     281.0                  283.2         0.2
# 76716                     281.9                  285.2         0.1
# 77030                     282.8                  281.5         0.0
# 77344                     295.7                  290.9         0.1
# 77658                     294.1                  294.4         0.1
# 77972                     289.9                  288.5         0.1
# 78286                     353.1                  352.8         0.1
# 78914                     243.1                  250.4         0.2
# 79228                     243.8                  242.5         0.0
# 79542                     271.8                  264.7         0.0
# 79856                     286.3                  292.5         0.1
# 80170                     288.3                  296.2         0.0
# 80484                     288.3                  282.4         0.6
# 80798                     287.7                  288.2         0.1
# 81112                     284.4                  287.5         0.0
# 81426                     309.8                  302.4         0.0
# 81740                     343.7                  336.3         0.0
# 82368                      17.0                   15.1         0.1
# 82682                     342.8                  342.7         0.0
# 82996                     303.5                  304.5         0.1
# 83310                     306.4                  308.3         0.1
# 83624                     309.4                  307.6         0.2
# 83938                     305.2                  305.8         0.8
# 83963                     305.2                  300.6         0.3
# 84252                     297.6                  301.8         0.2
# 84277                     297.6                  292.6         0.1
# 84565                     297.4                  301.8         0.1
# 84590                     297.4                  292.6         0.0
# 84880                     259.1                  267.4         0.2
# 84905                     259.1                  261.4         0.4
#
#        navigation_diff  distance_km  time_diff    navigation_time_nontug
# 68238              1.2     0.037093   0.050000 2021-04-07 19:26:56+00:00
# 68552              8.5     0.098622   0.033333 2021-04-07 19:31:55+00:00
# 69180              5.0     0.101213  -0.050000 2021-04-07 19:42:00+00:00
# 69494              0.1     0.098313   0.050000 2021-04-07 19:46:56+00:00
# 69808              2.9     0.099883   0.000000 2021-04-07 19:51:58+00:00
# 70122              0.6     0.097495  -0.033333 2021-04-07 19:57:00+00:00
# 70436              7.1     0.102090   0.000000 2021-04-07 20:01:57+00:00
# 70750              3.7     0.095502   0.050000 2021-04-07 20:06:57+00:00
# 71064              0.4     0.093954   0.016667 2021-04-07 20:11:56+00:00
# 71378              2.9     0.094901   0.083333 2021-04-07 20:16:55+00:00
# 71692              1.1     0.056960   0.183333 2021-04-07 20:21:47+00:00
# 72006              0.2     0.087735   0.033333 2021-04-07 20:26:56+00:00
# 72320              4.0     0.095848   0.066667 2021-04-07 20:31:56+00:00
# 72634              3.7     0.095906   0.050000 2021-04-07 20:36:55+00:00
# 72948              2.3     0.024185   0.683333 2021-04-07 20:41:17+00:00
# 73262              2.2     0.025575   0.700000 2021-04-07 20:46:17+00:00
# 73576              1.8     0.097791  -0.016667 2021-04-07 20:52:00+00:00
# 73890              2.4     0.058333   0.233333 2021-04-07 20:56:46+00:00
# 74204              3.5     0.161049   1.183333 2021-04-07 21:00:48+00:00
# 74518              1.5     0.094914   0.050000 2021-04-07 21:06:57+00:00
# 74832              3.7     0.092478   0.016667 2021-04-07 21:11:57+00:00
# 75146              2.7     0.053544   0.216667 2021-04-07 21:16:47+00:00
# 75460              1.9     0.094396   0.033333 2021-04-07 21:21:57+00:00
# 75774              0.5     0.087139   0.066667 2021-04-07 21:26:56+00:00
# 76088              7.0     0.014617   0.366667 2021-04-07 21:31:36+00:00
# 76402              2.2     0.085632   0.033333 2021-04-07 21:36:57+00:00
# 76716              3.3     0.088855   0.066667 2021-04-07 21:41:55+00:00
# 77030              1.3     0.095844   0.033333 2021-04-07 21:46:57+00:00
# 77344              4.8     0.098468   0.033333 2021-04-07 21:51:57+00:00
# 77658              0.3     0.097913   0.033333 2021-04-07 21:56:56+00:00
# 77972              1.4     0.098666   0.000000 2021-04-07 22:01:57+00:00
# 78286              0.3     0.103188   0.000000 2021-04-07 22:06:57+00:00
# 78914              7.3     0.099110   0.033333 2021-04-07 22:16:56+00:00
# 79228              1.3     0.099800   0.016667 2021-04-07 22:21:57+00:00
# 79542              7.1     0.096603   0.050000 2021-04-07 22:26:57+00:00
# 79856              6.2     0.095619   0.033333 2021-04-07 22:31:56+00:00
# 80170              7.9     0.090353   0.066667 2021-04-07 22:36:56+00:00
# 80484              5.9     0.095950   0.066667 2021-04-07 22:41:56+00:00
# 80798              0.5     0.067981   0.216667 2021-04-07 22:46:47+00:00
# 81112              3.1     0.107580   0.033333 2021-04-07 22:51:58+00:00
# 81426              7.4     0.104169   0.066667 2021-04-07 22:56:56+00:00
# 81740              7.4     0.106627   0.033333 2021-04-07 23:01:56+00:00
# 82368              1.9     0.097578   0.066667 2021-04-07 23:11:55+00:00
# 82682              0.1     0.106549   0.033333 2021-04-07 23:16:56+00:00
# 82996              1.0     0.106602   0.000000 2021-04-07 23:21:58+00:00
# 83310              1.9     0.107964   0.033333 2021-04-07 23:26:58+00:00
# 83624              1.8     0.139713   1.700000 2021-04-07 23:30:18+00:00
# 83938              0.6     0.047248   0.400000 2021-04-07 23:36:35+00:00
# 83963              4.6     0.203651   0.433333 2021-04-07 23:36:35+00:00
# 84252              4.2     0.037937   0.400000 2021-04-07 23:41:36+00:00
# 84277              5.0     0.180057   0.266667 2021-04-07 23:41:36+00:00
# 84565              4.4     0.094749  -0.116667 2021-04-07 23:42:07+00:00
# 84590              4.8     0.122666  -0.250000 2021-04-07 23:42:07+00:00
# 84880              8.3     0.083130  -0.083333 2021-04-07 23:52:05+00:00
# 84905              2.3     0.111025  -0.383333 2021-04-07 23:52:05+00:00

# %%
tugged_answer = pd.concat([
    tugs[tugs['index'].isin(filtered_columns['index_tug'])],
    non_tug[non_tug['index'].isin(filtered_columns['index_nontug'])]]
)

# %%
tugged_answer
# Out:
#      index vessel_type vessel_callsign vessel_subtype  vessel_imo vessel_name  \
# 4     1429         tug         WDD7182           None     9397391      SABINE
# 5     1430         tug         WDD7182           None     9397391      SABINE
# 7     1432         tug         WDD7182           None     9397391      SABINE
# 8     1433         tug         WDD7182           None     9397391      SABINE
# 9     1434         tug         WDD7182           None     9397391      SABINE
# ..     ...         ...             ...            ...         ...         ...
# 267    688       cargo           C6DD6            all     9770543     IRELAND
# 268    689       cargo           C6DD6            all     9770543     IRELAND
# 269    690       cargo           C6DD6            all     9770543     IRELAND
# 270    691       cargo           C6DD6            all     9770543     IRELAND
# 271    693       cargo           C6DD6            all     9770543     IRELAND
#
#      navigation_draught       navigation_status  navigation_location_long  \
# 4                   4.0  under-way-using-engine                 -93.95659
# 5                   4.0  under-way-using-engine                 -93.95972
# 7                   4.0  under-way-using-engine                 -93.95240
# 8                   4.0  under-way-using-engine                 -93.94748
# 9                   4.0  under-way-using-engine                 -93.94244
# ..                  ...                     ...                       ...
# 267                12.2  under-way-using-engine                 -94.05058
# 268                12.2  under-way-using-engine                 -94.05697
# 269                12.2  under-way-using-engine                 -94.06166
# 270                12.2  under-way-using-engine                 -94.06220
# 271                12.2  under-way-using-engine                 -94.07555
#
#      navigation_location_lat  navigation_speed           navigation_time  \
# 4                   29.81096               8.8 2021-04-07 19:26:59+00:00
# 5                   29.82188               8.2 2021-04-07 19:31:57+00:00
# 7                   29.84249               7.2 2021-04-07 19:41:57+00:00
# 8                   29.85031               5.4 2021-04-07 19:46:59+00:00
# 9                   29.85557               4.0 2021-04-07 19:51:58+00:00
# ..                       ...               ...                       ...
# 267                 30.06909               5.0 2021-04-07 23:30:18+00:00
# 268                 30.07383               3.4 2021-04-07 23:36:35+00:00
# 269                 30.07627               3.6 2021-04-07 23:41:36+00:00
# 270                 30.07650               3.7 2021-04-07 23:42:07+00:00
# 271                 30.07690               3.1 2021-04-07 23:52:05+00:00
#
#      navigation_course  device_mmsi  device_dimensions_to_bow  \
# 4                342.3    367182980                        15
# 5                  5.9    367182980                        15
# 7                 11.3    367182980                        15
# 8                 39.7    367182980                        15
# 9                 42.6    367182980                        15
# ..                 ...          ...                       ...
# 267              309.4    311000646                       196
# 268              305.2    311000646                       196
# 269              297.6    311000646                       196
# 270              297.4    311000646                       196
# 271              259.1    311000646                       196
#
#      device_dimensions_to_starboard  device_dimensions_to_stern  \
# 4                                 8                          15
# 5                                 8                          15
# 7                                 8                          15
# 8                                 8                          15
# 9                                 8                          15
# ..                              ...                         ...
# 267                              23                          33
# 268                              23                          33
# 269                              23                          33
# 270                              23                          33
# 271                              23                          33
#
#      device_dimensions_to_port                    geometry
# 4                            2  POINT (-93.95659 29.81096)
# 5                            2  POINT (-93.95972 29.82188)
# 7                            2   POINT (-93.9524 29.84249)
# 8                            2  POINT (-93.94748 29.85031)
# 9                            2  POINT (-93.94244 29.85557)
# ..                         ...                         ...
# 267                         10  POINT (-94.05058 30.06909)
# 268                         10  POINT (-94.05697 30.07383)
# 269                         10  POINT (-94.06166 30.07627)
# 270                         10    POINT (-94.0622 30.0765)
# 271                         10   POINT (-94.07555 30.0769)
#
# [104 rows x 19 columns]

# %%
# Create a GeoDataFrame named tugged_answer_gdf
tugged_answer_gdf = gpd.GeoDataFrame(tugged_answer, geometry='geometry')

# Sort the GeoDataFrame by 'vessel_name' and 'navigation_time'
tugged_answer_gdf = tugged_answer_gdf.sort_values(by=['vessel_name', 'navigation_time'])

# Define a function to create LineStrings from sorted points
def create_line(group):
    if len(group) > 1:
        return LineString(group['geometry'].tolist())
    else:
        return None

# Group the GeoDataFrame by 'unique_identifier' and apply the create_line function
lines_gdf = tugged_answer_gdf.groupby('vessel_name').apply(create_line).reset_index(name='geometry')

# Convert the resulting DataFrame to a GeoDataFrame
lines_gdf = gpd.GeoDataFrame(lines_gdf, geometry='geometry')

# Now, lines_gdf contains LineString geometries connecting points based on time order
print(lines_gdf)
# Out:
#   vessel_name                                           geometry
# 0   BUCCANEER  LINESTRING (-94.05880 30.07475, -94.06342 30.0...
# 1     IRELAND  LINESTRING (-93.95678 29.81125, -93.95947 29.8...
# 2      SABINE  LINESTRING (-93.95659 29.81096, -93.95972 29.8...

# %%
# Convert it to GeoJSON with a style function
def style_function(feature):
    # Define a list of colors you want to use for each row
    colors = ['red', 'blue', 'green']  # Add more colors as needed
    # Get the index of the current feature and select a color from the list
    color_index = feature['id'] % len(colors)
    color = colors[color_index]
    return {
        'color': color,
        'weight': 2,
        'opacity': 0.8,
    }

gdf = lines_gdf.set_crs(epsg=4326)

# Convert it to GeoJSON
geojson_data = gdf.to_json()
m = folium.Map(location=[30.0, -94.0], zoom_start=11)

# Add the GeoJSON data as a layer to the map
folium.GeoJson(geojson_data).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fd2d40852b70ba82c7f985fda10d5dd4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fd2d40852b70ba82c7f985fda10d5dd4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fd2d40852b70ba82c7f985fda10d5dd4 = L.map(
#                 &quot;map_fd2d40852b70ba82c7f985fda10d5dd4&quot;,
#                 {
#                     center: [30.0, -94.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_40a87f6a02c335395691b914cd322437 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_fd2d40852b70ba82c7f985fda10d5dd4);
#
#
#
#         function geo_json_61fa9741eb8a67a6734d99a9d51a69c5_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_61fa9741eb8a67a6734d99a9d51a69c5 = L.geoJson(null, {
#                 onEachFeature: geo_json_61fa9741eb8a67a6734d99a9d51a69c5_onEachFeature,
#
#         });
#
#         function geo_json_61fa9741eb8a67a6734d99a9d51a69c5_add (data) {
#             geo_json_61fa9741eb8a67a6734d99a9d51a69c5
#                 .addData(data)
#                 .addTo(map_fd2d40852b70ba82c7f985fda10d5dd4);
#         }
#             geo_json_61fa9741eb8a67a6734d99a9d51a69c5_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[-94.0588, 30.07475], [-94.06342, 30.07682], [-94.07667, 30.07666]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;vessel_name&quot;: &quot;BUCCANEER&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[-93.95678, 29.81125], [-93.95947, 29.82274], [-93.95218, 29.84338], [-93.947, 29.85109], [-93.94187, 29.85632], [-93.93782, 29.86038], [-93.93355, 29.86511], [-93.92834, 29.87312], [-93.92043, 29.88178], [-93.91196, 29.89105], [-93.90312, 29.89915], [-93.89496, 29.90781], [-93.8882, 29.91489], [-93.8832, 29.9203], [-93.87878, 29.92524], [-93.87471, 29.92973], [-93.86915, 29.93624], [-93.86385, 29.94461], [-93.86053, 29.95263], [-93.85631, 29.96268], [-93.85673, 29.9725], [-93.86524, 29.97933], [-93.87606, 29.98109], [-93.88406, 29.98225], [-93.89378, 29.9838], [-93.90702, 29.98604], [-93.91967, 29.98832], [-93.92877, 29.99008], [-93.93529, 29.99193], [-93.94144, 29.99442], [-93.94842, 29.99706], [-93.95455, 30.00452], [-93.96852, 30.01237], [-93.97403, 30.00998], [-93.97958, 30.00856], [-93.98587, 30.00968], [-93.99283, 30.01176], [-94.00247, 30.01422], [-94.01369, 30.01735], [-94.02212, 30.01966], [-94.0282, 30.02276], [-94.03182, 30.02785], [-94.02935, 30.04381], [-94.02904, 30.05396], [-94.03645, 30.06153], [-94.04621, 30.06589], [-94.05058, 30.06909], [-94.05697, 30.07383], [-94.06166, 30.07627], [-94.0622, 30.0765], [-94.07555, 30.0769]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;vessel_name&quot;: &quot;IRELAND&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[-93.95659, 29.81096], [-93.95972, 29.82188], [-93.9524, 29.84249], [-93.94748, 29.85031], [-93.94244, 29.85557], [-93.93838, 29.85965], [-93.93381, 29.86422], [-93.92888, 29.8724], [-93.92094, 29.88106], [-93.91247, 29.89032], [-93.90338, 29.89869], [-93.89538, 29.90711], [-93.88871, 29.91415], [-93.88373, 29.91957], [-93.87861, 29.92508], [-93.87471, 29.9295], [-93.86968, 29.93549], [-93.86393, 29.94409], [-93.85977, 29.95392], [-93.85654, 29.96185], [-93.85627, 29.97177], [-93.86469, 29.97926], [-93.87508, 29.9811], [-93.88316, 29.98217], [-93.89363, 29.98378], [-93.90614, 29.98593], [-93.91875, 29.98826], [-93.92779, 29.98993], [-93.93432, 29.99165], [-93.94048, 29.99413], [-93.94746, 29.99675], [-93.95434, 30.00361], [-93.96771, 30.01292], [-93.97314, 30.01044], [-93.97858, 30.00863], [-93.98491, 30.00946], [-93.99193, 30.01153], [-94.00154, 30.01391], [-94.01299, 30.01727], [-94.02102, 30.01949], [-94.0273, 30.02224], [-94.03138, 30.02697], [-94.02974, 30.043], [-94.02866, 30.05306], [-94.03541, 30.0612], [-94.04527, 30.06536], [-94.05167, 30.06992], [-94.05652, 30.07366], [-94.06127, 30.07622], [-94.07474, 30.07716]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;2&quot;, &quot;properties&quot;: {&quot;vessel_name&quot;: &quot;SABINE&quot;}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import geopandas as gpd
from shapely.geometry import LineString
from itertools import tee, islice



# Sort the GeoDataFrame by 'vessel_name' and 'navigation_time'
tugged_answer_gdf = tugged_answer_gdf.sort_values(by=['vessel_name', 'navigation_time'])

# Create a function to pair consecutive rows in a group
def pairwise(iterable):
    a, b = tee(iterable)
    next(b, None)
    return zip(a, b)

# Create an empty list to store LineString geometries
tugged_answer_gdf['line_geometry'] = None

# Iterate through groups based on 'vessel_name'
for vessel_name, group in tugged_answer_gdf.groupby('vessel_name'):
    # Iterate through consecutive rows in the group
    for (idx1, row1), (idx2, row2) in pairwise(group.iterrows()):
        # Create a LineString between the current and next point
        line = LineString([row1.geometry, row2.geometry])
        tugged_answer_gdf.at[idx1, 'line_geometry'] = line


# Now, lines_gdf contains LineString geometries for each row connecting the current point to the next point based on time order
tugged_answer_gdf.set_geometry('line_geometry',inplace=True)

# %%
tugged_answer_gdf_plot = tugged_answer_gdf[[
    'vessel_name',
    'navigation_speed',
    'line_geometry']]

tugged_answer_gdf_plot = tugged_answer_gdf_plot.dropna()
tugged_answer_gdf_plot.set_crs(epsg=4326)

# Convert it to GeoJSON
geojson_data = tugged_answer_gdf_plot.to_json()

# %%
# Define the color-coding based on speed (adjust vmin and vmax accordingly)
speed_col = tugged_answer['navigation_speed']
cmap = plt.get_cmap('viridis')  # Choose a colormap
normalize = Normalize(vmin=speed_col.min(), vmax=speed_col.max())

# %%
fig, ax = plt.subplots(figsize=(10, 10))

for boat in tugged_answer['vessel_name'].unique():
    vessel_data = tugged_answer[tugged_answer['vessel_name'] == boat]
    vessel_data.reset_index(inplace=True)

    #print(vessel_data.vessel_name[0], boat)
    for idx, row in vessel_data.iterrows():
        start_lon = row['navigation_location_long']
        start_lat = row['navigation_location_lat']
        end_idx = idx + 1 if idx + 1 < len(vessel_data) else idx
        end_lon = vessel_data.loc[end_idx, 'navigation_location_long']
        end_lat = vessel_data.loc[end_idx, 'navigation_location_lat']
        arrow_color = cmap(normalize(row['navigation_speed']))
    #print(idx, start_lon, start_lat,end_idx, end_lon,end_lat)
        
        arrow = mpatches.FancyArrowPatch(
            (start_lon, start_lat),
            (end_lon, end_lat),
            color=arrow_color,
            arrowstyle='-|>',
            mutation_scale=15,
            lw=1,
            alpha=0.7
        )
        ax.add_patch(arrow)

# Add color bar
sm = ScalarMappable(cmap=cmap, norm=normalize)
sm.set_array([])  # Empty array to ensure the scale corresponds to the speed values
cbar = plt.colorbar(sm, ax=ax, label='Speed')
ax.set(
    xlim=(
        max(vessel_data['navigation_location_long']), 
        min(vessel_data['navigation_location_long'])), 
    ylim=(
        min(vessel_data['navigation_location_lat']), 
        max(vessel_data['navigation_location_lat'])))

# Show the plot or save it
plt.show()

# %%
# Parse the GeoJSON string into a dictionary
geojson_data = json.loads(geojson_data)

# %%
geojson_data
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'id': '79',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'BUCCANEER', 'navigation_speed': 3.7},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-94.0588, 30.07475], [-94.06342, 30.07682]]}},
#   {'id': '80',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'BUCCANEER', 'navigation_speed': 3.7},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-94.06342, 30.07682], [-94.07667, 30.07666]]}},
#   {'id': '218',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'IRELAND', 'navigation_speed': 8.7},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.95678, 29.81125], [-93.95947, 29.82274]]}},
#   {'id': '219',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'IRELAND', 'navigation_speed': 8.0},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.95947, 29.82274], [-93.95218, 29.84338]]}},
#   {'id': '221',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'IRELAND', 'navigation_speed': 7.1},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.95218, 29.84338], [-93.947, 29.85109]]}},
#   {'id': '222',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'IRELAND', 'navigation_speed': 5.5},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.947, 29.85109], [-93.94187, 29.85632]]}},
#   {'id': '223',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'IRELAND', 'navigation_speed': 4.1},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.94187, 29.85632], [-93.93782, 29.86038]]}},
#   {'id': '224',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'IRELAND', 'navigation_speed': 3.9},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.93782, 29.86038], [-93.93355, 29.86511]]}},
#   {'id': '225',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'IRELAND', 'navigation_speed': 5.2},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.93355, 29.86511], [-93.92834, 29.87312]]}},
#   {'id': '226',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'IRELAND', 'navigation_speed': 7.4},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.92834, 29.87312], [-93.92043, 29.88178]]}},
#   {'id': '227',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'IRELAND', 'navigation_speed': 8.2},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.92043, 29.88178], [-93.91196, 29.89105]]}},
#   {'id': '228',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'IRELAND', 'navigation_speed': 8.6},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.91196, 29.89105], [-93.90312, 29.89915]]}},
#   {'id': '229',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'IRELAND', 'navigation_speed': 8.0},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.90312, 29.89915], [-93.89496, 29.90781]]}},
#   {'id': '230',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'IRELAND', 'navigation_speed': 7.6},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.89496, 29.90781], [-93.8882, 29.91489]]}},
#   {'id': '231',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'IRELAND', 'navigation_speed': 5.3},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.8882, 29.91489], [-93.8832, 29.9203]]}},
#   {'id': '232',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'IRELAND', 'navigation_speed': 5.1},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.8832, 29.9203], [-93.87878, 29.92524]]}},
#   {'id': '233',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'IRELAND', 'navigation_speed': 4.9},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.87878, 29.92524], [-93.87471, 29.92973]]}},
#   {'id': '234',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'IRELAND', 'navigation_speed': 3.8},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.87471, 29.92973], [-93.86915, 29.93624]]}},
#   {'id': '235',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'IRELAND', 'navigation_speed': 6.5},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.86915, 29.93624], [-93.86385, 29.94461]]}},
#   {'id': '236',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'IRELAND', 'navigation_speed': 7.5},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.86385, 29.94461], [-93.86053, 29.95263]]}},
#   {'id': '237',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'IRELAND', 'navigation_speed': 7.5},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.86053, 29.95263], [-93.85631, 29.96268]]}},
#   {'id': '238',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'IRELAND', 'navigation_speed': 6.3},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.85631, 29.96268], [-93.85673, 29.9725]]}},
#   {'id': '239',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'IRELAND', 'navigation_speed': 7.7},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.85673, 29.9725], [-93.86524, 29.97933]]}},
#   {'id': '240',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'IRELAND', 'navigation_speed': 7.5},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.86524, 29.97933], [-93.87606, 29.98109]]}},
#   {'id': '241',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'IRELAND', 'navigation_speed': 5.3},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.87606, 29.98109], [-93.88406, 29.98225]]}},
#   {'id': '242',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'IRELAND', 'navigation_speed': 5.5},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.88406, 29.98225], [-93.89378, 29.9838]]}},
#   {'id': '243',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'IRELAND', 'navigation_speed': 7.3},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.89378, 29.9838], [-93.90702, 29.98604]]}},
#   {'id': '244',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'IRELAND', 'navigation_speed': 8.3},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.90702, 29.98604], [-93.91967, 29.98832]]}},
#   {'id': '245',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'IRELAND', 'navigation_speed': 7.3},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.91967, 29.98832], [-93.92877, 29.99008]]}},
#   {'id': '246',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'IRELAND', 'navigation_speed': 4.3},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.92877, 29.99008], [-93.93529, 29.99193]]}},
#   {'id': '247',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'IRELAND', 'navigation_speed': 4.2},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.93529, 29.99193], [-93.94144, 29.99442]]}},
#   {'id': '248',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'IRELAND', 'navigation_speed': 4.1},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.94144, 29.99442], [-93.94842, 29.99706]]}},
#   {'id': '249',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'IRELAND', 'navigation_speed': 5.9},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.94842, 29.99706], [-93.95455, 30.00452]]}},
#   {'id': '250',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'IRELAND', 'navigation_speed': 7.3},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.95455, 30.00452], [-93.96852, 30.01237]]}},
#   {'id': '252',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'IRELAND', 'navigation_speed': 4.5},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.96852, 30.01237], [-93.97403, 30.00998]]}},
#   {'id': '253',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'IRELAND', 'navigation_speed': 3.6},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.97403, 30.00998], [-93.97958, 30.00856]]}},
#   {'id': '254',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'IRELAND', 'navigation_speed': 3.6},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.97958, 30.00856], [-93.98587, 30.00968]]}},
#   {'id': '255',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'IRELAND', 'navigation_speed': 4.3},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.98587, 30.00968], [-93.99283, 30.01176]]}},
#   {'id': '256',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'IRELAND', 'navigation_speed': 5.0},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.99283, 30.01176], [-94.00247, 30.01422]]}},
#   {'id': '257',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'IRELAND', 'navigation_speed': 7.2},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-94.00247, 30.01422], [-94.01369, 30.01735]]}},
#   {'id': '258',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'IRELAND', 'navigation_speed': 7.0},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-94.01369, 30.01735], [-94.02212, 30.01966]]}},
#   {'id': '259',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'IRELAND', 'navigation_speed': 4.4},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-94.02212, 30.01966], [-94.0282, 30.02276]]}},
#   {'id': '260',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'IRELAND', 'navigation_speed': 4.4},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-94.0282, 30.02276], [-94.03182, 30.02785]]}},
#   {'id': '261',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'IRELAND', 'navigation_speed': 4.2},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-94.03182, 30.02785], [-94.02935, 30.04381]]}},
#   {'id': '263',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'IRELAND', 'navigation_speed': 7.3},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-94.02935, 30.04381], [-94.02904, 30.05396]]}},
#   {'id': '264',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'IRELAND', 'navigation_speed': 7.5},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-94.02904, 30.05396], [-94.03645, 30.06153]]}},
#   {'id': '265',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'IRELAND', 'navigation_speed': 7.4},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-94.03645, 30.06153], [-94.04621, 30.06589]]}},
#   {'id': '266',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'IRELAND', 'navigation_speed': 5.8},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-94.04621, 30.06589], [-94.05058, 30.06909]]}},
#   {'id': '267',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'IRELAND', 'navigation_speed': 5.0},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-94.05058, 30.06909], [-94.05697, 30.07383]]}},
#   {'id': '268',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'IRELAND', 'navigation_speed': 3.4},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-94.05697, 30.07383], [-94.06166, 30.07627]]}},
#   {'id': '269',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'IRELAND', 'navigation_speed': 3.6},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-94.06166, 30.07627], [-94.0622, 30.0765]]}},
#   {'id': '270',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'IRELAND', 'navigation_speed': 3.7},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-94.0622, 30.0765], [-94.07555, 30.0769]]}},
#   {'id': '4',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'SABINE', 'navigation_speed': 8.8},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.95659, 29.81096], [-93.95972, 29.82188]]}},
#   {'id': '5',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'SABINE', 'navigation_speed': 8.2},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.95972, 29.82188], [-93.9524, 29.84249]]}},
#   {'id': '7',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'SABINE', 'navigation_speed': 7.2},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.9524, 29.84249], [-93.94748, 29.85031]]}},
#   {'id': '8',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'SABINE', 'navigation_speed': 5.4},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.94748, 29.85031], [-93.94244, 29.85557]]}},
#   {'id': '9',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'SABINE', 'navigation_speed': 4.0},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.94244, 29.85557], [-93.93838, 29.85965]]}},
#   {'id': '10',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'SABINE', 'navigation_speed': 4.0},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.93838, 29.85965], [-93.93381, 29.86422]]}},
#   {'id': '11',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'SABINE', 'navigation_speed': 5.4},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.93381, 29.86422], [-93.92888, 29.8724]]}},
#   {'id': '12',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'SABINE', 'navigation_speed': 7.5},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.92888, 29.8724], [-93.92094, 29.88106]]}},
#   {'id': '13',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'SABINE', 'navigation_speed': 8.3},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.92094, 29.88106], [-93.91247, 29.89032]]}},
#   {'id': '14',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'SABINE', 'navigation_speed': 8.7},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.91247, 29.89032], [-93.90338, 29.89869]]}},
#   {'id': '15',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'SABINE', 'navigation_speed': 8.0},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.90338, 29.89869], [-93.89538, 29.90711]]}},
#   {'id': '16',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'SABINE', 'navigation_speed': 7.7},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.89538, 29.90711], [-93.88871, 29.91415]]}},
#   {'id': '17',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'SABINE', 'navigation_speed': 5.3},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.88871, 29.91415], [-93.88373, 29.91957]]}},
#   {'id': '18',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'SABINE', 'navigation_speed': 5.1},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.88373, 29.91957], [-93.87861, 29.92508]]}},
#   {'id': '19',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'SABINE', 'navigation_speed': 4.6},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.87861, 29.92508], [-93.87471, 29.9295]]}},
#   {'id': '20',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'SABINE', 'navigation_speed': 4.0},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.87471, 29.9295], [-93.86968, 29.93549]]}},
#   {'id': '21',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'SABINE', 'navigation_speed': 6.6},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.86968, 29.93549], [-93.86393, 29.94409]]}},
#   {'id': '22',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'SABINE', 'navigation_speed': 7.5},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.86393, 29.94409], [-93.85977, 29.95392]]}},
#   {'id': '23',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'SABINE', 'navigation_speed': 6.7},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.85977, 29.95392], [-93.85654, 29.96185]]}},
#   {'id': '24',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'SABINE', 'navigation_speed': 6.4},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.85654, 29.96185], [-93.85627, 29.97177]]}},
#   {'id': '25',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'SABINE', 'navigation_speed': 7.8},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.85627, 29.97177], [-93.86469, 29.97926]]}},
#   {'id': '26',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'SABINE', 'navigation_speed': 7.6},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.86469, 29.97926], [-93.87508, 29.9811]]}},
#   {'id': '27',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'SABINE', 'navigation_speed': 5.3},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.87508, 29.9811], [-93.88316, 29.98217]]}},
#   {'id': '28',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'SABINE', 'navigation_speed': 5.5},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.88316, 29.98217], [-93.89363, 29.98378]]}},
#   {'id': '29',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'SABINE', 'navigation_speed': 7.4},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.89363, 29.98378], [-93.90614, 29.98593]]}},
#   {'id': '30',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'SABINE', 'navigation_speed': 8.5},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.90614, 29.98593], [-93.91875, 29.98826]]}},
#   {'id': '31',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'SABINE', 'navigation_speed': 7.4},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.91875, 29.98826], [-93.92779, 29.98993]]}},
#   {'id': '32',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'SABINE', 'navigation_speed': 4.3},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.92779, 29.98993], [-93.93432, 29.99165]]}},
#   {'id': '33',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'SABINE', 'navigation_speed': 4.3},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.93432, 29.99165], [-93.94048, 29.99413]]}},
#   {'id': '34',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'SABINE', 'navigation_speed': 4.2},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.94048, 29.99413], [-93.94746, 29.99675]]}},
#   {'id': '35',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'SABINE', 'navigation_speed': 6.0},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.94746, 29.99675], [-93.95434, 30.00361]]}},
#   {'id': '36',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'SABINE', 'navigation_speed': 7.4},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.95434, 30.00361], [-93.96771, 30.01292]]}},
#   {'id': '38',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'SABINE', 'navigation_speed': 4.7},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.96771, 30.01292], [-93.97314, 30.01044]]}},
#   {'id': '39',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'SABINE', 'navigation_speed': 3.6},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.97314, 30.01044], [-93.97858, 30.00863]]}},
#   {'id': '40',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'SABINE', 'navigation_speed': 3.6},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.97858, 30.00863], [-93.98491, 30.00946]]}},
#   {'id': '41',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'SABINE', 'navigation_speed': 4.4},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.98491, 30.00946], [-93.99193, 30.01153]]}},
#   {'id': '42',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'SABINE', 'navigation_speed': 5.0},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-93.99193, 30.01153], [-94.00154, 30.01391]]}},
#   {'id': '43',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'SABINE', 'navigation_speed': 6.6},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-94.00154, 30.01391], [-94.01299, 30.01727]]}},
#   {'id': '44',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'SABINE', 'navigation_speed': 6.9},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-94.01299, 30.01727], [-94.02102, 30.01949]]}},
#   {'id': '45',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'SABINE', 'navigation_speed': 4.4},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-94.02102, 30.01949], [-94.0273, 30.02224]]}},
#   {'id': '46',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'SABINE', 'navigation_speed': 4.4},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-94.0273, 30.02224], [-94.03138, 30.02697]]}},
#   {'id': '47',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'SABINE', 'navigation_speed': 4.2},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-94.03138, 30.02697], [-94.02974, 30.043]]}},
#   {'id': '49',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'SABINE', 'navigation_speed': 7.4},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-94.02974, 30.043], [-94.02866, 30.05306]]}},
#   {'id': '50',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'SABINE', 'navigation_speed': 7.5},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-94.02866, 30.05306], [-94.03541, 30.0612]]}},
#   {'id': '51',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'SABINE', 'navigation_speed': 7.5},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-94.03541, 30.0612], [-94.04527, 30.06536]]}},
#   {'id': '52',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'SABINE', 'navigation_speed': 5.9},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-94.04527, 30.06536], [-94.05167, 30.06992]]}},
#   {'id': '53',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'SABINE', 'navigation_speed': 4.8},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-94.05167, 30.06992], [-94.05652, 30.07366]]}},
#   {'id': '54',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'SABINE', 'navigation_speed': 4.2},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-94.05652, 30.07366], [-94.06127, 30.07622]]}},
#   {'id': '55',
#    'type': 'Feature',
#    'properties': {'vessel_name': 'SABINE', 'navigation_speed': 3.8},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[-94.06127, 30.07622], [-94.07474, 30.07716]]}}]}

# %%
# Create a folium map centered on the first feature
map_center = [tugged_answer['navigation_location_lat'].mean(), tugged_answer['navigation_location_long'].mean()]
m = folium.Map(location=map_center, zoom_start=10)

# Define a function to determine color based on speed
def color_speed(speed):
    if speed < 2.5:
        return 'blue'
    elif speed < 5:
        return 'yellow'
    else:
        return 'green'

# Add LineString geometries with speed-based colors to the map
for feature in geojson_data["features"]:
    speed = feature["properties"]["navigation_speed"]
    color = color_speed(speed)
    line_string = json.dumps(feature["geometry"])
    folium.GeoJson(
        line_string,
        style_function=lambda x, color=color: {
            'color': color,
            'weight': 1.5
        },
        tooltip=feature["properties"]["vessel_name"]
    ).add_to(m)

folium.TileLayer('cartodbpositron').add_to(m)


# Save the map to an HTML file
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_487e2283b318eb619483661b220bfd4d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_487e2283b318eb619483661b220bfd4d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_487e2283b318eb619483661b220bfd4d = L.map(
#                 &quot;map_487e2283b318eb619483661b220bfd4d&quot;,
#                 {
#                     center: [29.971539711538462, -93.95348759615385],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4a4fd499de2fd967d32da1dd13ee486f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_487e2283b318eb619483661b220bfd4d);
#
#
#         function geo_json_2417121cc572225d6d53849f60de336a_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;yellow&quot;, &quot;weight&quot;: 1.5};
#             }
#         }
#
#         function geo_json_2417121cc572225d6d53849f60de336a_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_2417121cc572225d6d53849f60de336a = L.geoJson(null, {
#                 onEachFeature: geo_json_2417121cc572225d6d53849f60de336a_onEachFeature,
#
#                 style: geo_json_2417121cc572225d6d53849f60de336a_styler,
#         });
#
#         function geo_json_2417121cc572225d6d53849f60de336a_add (data) {
#             geo_json_2417121cc572225d6d53849f60de336a
#                 .addData(data)
#                 .addTo(map_487e2283b318eb619483661b220bfd4d);
#         }
#             geo_json_2417121cc572225d6d53849f60de336a_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[-94.0588, 30.07475], [-94.06342, 30.07682]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_2417121cc572225d6d53849f60de336a.bindTooltip(
#                 `&lt;div&gt;
#                      BUCCANEER
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#         function geo_json_538e2ffc6d2490b10fe16df8c3579983_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;yellow&quot;, &quot;weight&quot;: 1.5};
#             }
#         }
#
#         function geo_json_538e2ffc6d2490b10fe16df8c3579983_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_538e2ffc6d2490b10fe16df8c3579983 = L.geoJson(null, {
#                 onEachFeature: geo_json_538e2ffc6d2490b10fe16df8c3579983_onEachFeature,
#
#                 style: geo_json_538e2ffc6d2490b10fe16df8c3579983_styler,
#         });
#
#         function geo_json_538e2ffc6d2490b10fe16df8c3579983_add (data) {
#             geo_json_538e2ffc6d2490b10fe16df8c3579983
#                 .addData(data)
#                 .addTo(map_487e2283b318eb619483661b220bfd4d);
#         }
#             geo_json_538e2ffc6d2490b10fe16df8c3579983_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[-94.06342, 30.07682], [-94.07667, 30.07666]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_538e2ffc6d2490b10fe16df8c3579983.bindTooltip(
#                 `&lt;div&gt;
#                      BUCCANEER
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#         function geo_json_eaea63fd161294b7a7df9acda3bf2fb2_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;green&quot;, &quot;weight&quot;: 1.5};
#             }
#         }
#
#         function geo_json_eaea63fd161294b7a7df9acda3bf2fb2_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_eaea63fd161294b7a7df9acda3bf2fb2 = L.geoJson(null, {
#                 onEachFeature: geo_json_eaea63fd161294b7a7df9acda3bf2fb2_onEachFeature,
#
#                 style: geo_json_eaea63fd161294b7a7df9acda3bf2fb2_styler,
#         });
#
#         function geo_json_eaea63fd161294b7a7df9acda3bf2fb2_add (data) {
#             geo_json_eaea63fd161294b7a7df9acda3bf2fb2
#                 .addData(data)
#                 .addTo(map_487e2283b318eb619483661b220bfd4d);
#         }
#             geo_json_eaea63fd161294b7a7df9acda3bf2fb2_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[-93.95678, 29.81125], [-93.95947, 29.82274]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quo

# %% [markdown]
# Visual comparison of naviguation speeds of 2 chosen vessels:

# %%
# Create a Dash app
app = dash.Dash(__name__)

# Define the app layout
app.layout = html.Div([
    dcc.Dropdown(id='vessel-selector-1', multi=False, placeholder="Select Vessel 1"),
    dcc.Dropdown(id='vessel-selector-2', multi=False, placeholder="Select Vessel 2"),
    dcc.Graph(id='speed-comparison'),
])

# Create a color map to assign unique colors to vessels
vessel_colors = px.colors.qualitative.Set3

# Populate the dropdown menus with vessel names
vessel_dropdown = [{"label": vessel_name, "value": vessel_name} for vessel_name in data['vessel_name'].unique()]
@app.callback(
    Output('vessel-selector-1', 'options'),
    Output('vessel-selector-2', 'options'),
    Input('vessel-selector-1', 'value'),
    Input('vessel-selector-2', 'value')
)
def update_vessel_options(selected_vessel_1, selected_vessel_2):
    # Exclude the selected vessel from the other dropdown
    available_vessels = [vessel for vessel in data['vessel_name'].unique() if vessel != selected_vessel_1]
    
    return ([{"label": vessel, "value": vessel} for vessel in available_vessels],
            [{"label": vessel, "value": vessel} for vessel in available_vessels])

# Define callback function to update speed comparison graph
@app.callback(
    Output('speed-comparison', 'figure'),
    Input('vessel-selector-1', 'value'),
    Input('vessel-selector-2', 'value')
)
def update_speed_comparison(selected_vessel_1, selected_vessel_2):
    if selected_vessel_1 is None or selected_vessel_2 is None:
        return go.Figure()
    
    # Filter data for the selected vessels
    selected_vessel_data_1 = data[data['vessel_name'] == selected_vessel_1]
    selected_vessel_data_2 = data[data['vessel_name'] == selected_vessel_2]
    
    # Assign unique colors to the selected vessels
    color_1 = vessel_colors[0]
    color_2 = vessel_colors[1]
    
    # Create line traces for the selected vessels
    trace_1 = go.Scatter(x=selected_vessel_data_1['navigation_time'], y=selected_vessel_data_1['navigation_speed'],
                         mode='lines+markers', hoverinfo='x+y',
                         text=selected_vessel_data_1['navigation_time'].dt.strftime('%Y-%m-%d %H:%M:%S'),
                         line=dict(color=color_1), name=selected_vessel_1)
    trace_2 = go.Scatter(x=selected_vessel_data_2['navigation_time'], y=selected_vessel_data_2['navigation_speed'],
                         mode='lines+markers', hoverinfo='x+y',
                         text=selected_vessel_data_2['navigation_time'].dt.strftime('%Y-%m-%d %H:%M:%S'),
                         line=dict(color=color_2), name=selected_vessel_2)
    
    # Create the speed comparison graph
    fig = make_subplots(rows=1, cols=1, subplot_titles=("Speed Comparison",))
    fig.add_trace(trace_1)
    fig.add_trace(trace_2)
    fig.update_layout(
        title_text=f'Speed comparison between {selected_vessel_1} and {selected_vessel_2}',
        xaxis_title='Time',
        yaxis_title='Navigation speed',
        xaxis=dict(tickangle=-45),
    )
    
    return fig

# Run the Dash app
if __name__ == '__main__':
    app.run_server(debug=True, use_reloader=False)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# /Users/Sarah/opt/anaconda3/envs/CIEM6302/lib/python3.10/site-packages/_plotly_utils/basevalidators.py:105: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#
# /Users/Sarah/opt/anaconda3/envs/CIEM6302/lib/python3.10/site-packages/_plotly_utils/basevalidators.py:105: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result

# %% [markdown]
# Additional visualizations can be found in the "AdditionalVisualizations.ipynb" file. These concern more general visualizations of the data set.

# %% [markdown]
# **Data Ethics**

# %% [markdown]
# For our particular project, we have a dataset that mostly comprises of tugboat or other vessel monitoring data without any direct or sensitive human information. This trait considerably narrows the scope of some ethical issues that are frequently connected to data science projects. For instance, a number of issues, like as privacy and informed permission, become less important because we are primarily dealing with vessel-related data rather than direct human data. We nevertheless used the seminar's information in our project to take the ethical implications of data science into consideration and to apply it to our project.
#
# The ethical aspects we should consider for this vessel tracking and prediction project are the following:
#
# 1. Value-sensitive design:
#
#    - Consider stakeholder values: Identify the major parties involved in our project, such as port authorities, environmental organisations, coastal communities and vessel operators. Surveys, interviews or focus groups can be used to learn about people's attitudes towards vessel tracking and tug prediction.
#    - Transparency: Transparency is implemented by outlining data sources, processing strategies and model algorithms. Make sure stakeholders can easily grasp the construction and use of our prediction models.
#    - Value trade-offs: We have to be aware of potential conflicts between the values of various stakeholders. For instance, whereas coastal communities may put more emphasis on environmental protection, vessel operators may prioritise cost-effectiveness and efficiency. Trade-offs should be communicated in detail when they occur and stakeholders should be involved in moral decision-making.Indeed, the goal of tugboat operators and port authorities may not be consistent, which highly relies on the design logic of the tugboat assignment algorithm. We should ensure fairness in task allocation to different tugboat companies. Besides, while designing the algorithm, the emission pollution could be taken into account as well to align with the goal of environmental organizations. However, that last point goes beyond the project boundaries and would present a huge challenge.
#
#
#
# 2. Privacy:
#
#    - Data minimization: We only will gather the information required to achieve the goals of our project. Keep data collection to the most pertinent tracking and vessel parameters, minimising intrusive or unnecessary details.
#    - Anonymization: To safeguard the identities of vessel operators and crew members, sensitive data should be pseudonymized or anonymized. Only transmit or store personally identifiable information (PII) when it is absolutely necessary for compliance or safety reasons. However,  in the provided data set, we do not have such data. In case we add other additional data, we should pay attention to this. If this additional data involves personal information, we should establish a clear and transparent consent mechanism. We have to provide vessel operators with information on data usage and obtain their informed consent.
#    - Data security: Implement robust data security measures. However, once again here, we do not have very sensible data. Most vessel data can be reached on public websites. Whereas, during the whole service process, the AIS location data (specific coordinates) for vessels are required, which should only be notified to the service company responsible for tugging.
#
# 3. Bias:
#
#    - Preexisting bias: Check our vessel tracking data for biases in great detail. Bias may be caused by past data-gathering methods or by the underrepresentation of particular vessel types or geographic areas.
#    - Technical bias: During development, we have to keep an eye out for and audit our machine learning models for technical bias. We have to examine whether certain vessel types, routes, or operators are disproportionately impacted by the models. In the training part, the selection of objects should contain all possible categories to avoid bias in the predictions.
#    - Emergent bias: Even though this step is further in the process than our project, during deployment, one has to keep checking our models for emerging biases. It includes gathering user and stakeholder opinions about any apparent biases or discrepancies in model predictions and recalibrating models frequently to reduce emergent biases that might appear in real-world situations.
#    - Easy to use. The designed prediction algorithm should be easily understandable by operators and users.
#
# 4. Fairness:
#
#    - Fair model metrics: Choice of fairness metrics that are consistent with the goals of our project. Consideration of indicators like disparate impact to assess whether the model's suggestions are equitable across various vessel types or operators, for instance, if fairness in tug allocation is important.
#    - Bias Mitigation: As part of our model development process, we can use bias mitigation approaches. These methods should be put to the test and refined to make sure they don't add new biases or have a detrimental effect on model performance.
#
# 5. Ethical review and compliance:
#
#    - To make sure that our project complies with industry-specific and ethical norms, we could consult ethics committees or specialists in marine ethics and data privacy.
#
# 6. Continuous evaluation and improvement:
#
#    - We could assess the ethical compliance of the project on a regular basis and adapt as ethical considerations and stakeholder comments change.
#
#
#
# While it is our aspiration to address all ethical considerations outlined above, we understand that practical constraints and project-specific circumstances may limit our ability to fully implement each point.~~~~
#
# Our aim is not only to implement ethical safeguards where possible but also to approach our project with a heightened sensitivity to the ethical dimensions it encompasses. We are aware and try to take care of the value of engaging with stakeholders, maintaining transparency and continuously striving for fairness and privacy protection.
